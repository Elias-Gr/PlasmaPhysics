# %%
from simsopt.geo import SurfaceRZFourier, create_equally_spaced_curves, \
    CurveLength, curves_to_vtk
import simsopt.geo.plotting as sims
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import minimize
from simsopt.geo import plot

# %%
nphi = 32
ntheta = 32
s = SurfaceRZFourier.from_vmec_input('input', range="full torus", nphi=nphi, ntheta=ntheta)

# %%
plot([s])
# Out:
# <Axes3D: >

# %%
base_curves = create_equally_spaced_curves(16, s.nfp, stellsym=True, R0=0.5, R1=1, order=5)

# %%
plot([s]+base_curves)
# Out:
# <Axes3D: >
